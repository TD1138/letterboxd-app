# %%
import numpy as np, pandas as pd
import sqlite3 as sql
import os
# import seaborn as sns
# import plotly.graph_objs as go
from dotenv import load_dotenv
import sys
sys.path.insert(0, '../data_prep')
from sqlite_utils import get_list_of_tables, get_from_table

load_dotenv()

def print_film_db_entries(film_id):
    try:
        film_title = get_from_table('FILM_TITLE', film_id, 'FILM_TITLE')
    except:
        film_title = 'MISSING!!!'
    for table in get_list_of_tables():
        try:
            entry = get_from_table(table, film_id)
            print('\nEntry for {} ({}) in the {} table is:\n{}'.format(film_title, film_id, table, entry))
        except:
            print('\nNo Entry for {} ({}) in the {} table.'.format(film_title, film_id, table))

def compare_film_db_entries(film_ids):
    for table in get_list_of_tables():
        for film_id in film_ids:
            try:
                film_title = get_from_table('FILM_TITLE', film_id, 'FILM_TITLE')
            except:
                film_title = 'MISSING!!!'
            try:
                entry = get_from_table(table, film_id)
                print('\nEntry for {} ({}) in the {} table is:\n{}'.format(film_title, film_id, table, entry))
            except:
                print('\nNo Entry for {} ({}) in the {} table.'.format(film_title, film_id, table))




print_film_db_entries('f_0hTha')
# Out:
# Entry for Parasite (f_0hTha) in the FILM_YEAR table is:
# {'FILM_ID': 'f_0hTha', 'FILM_YEAR': 2019, 'FILM_DECADE': '2010s', 'CREATED_AT': '2023-05-25 18:41:56.053461'}
#
# Entry for Parasite (f_0hTha) in the FILM_LETTERBOXD_STATS table is:
# {'FILM_ID': 'f_0hTha', 'FILM_WATCH_COUNT': 3527322, 'FILM_FAN_COUNT': 83457, 'FILM_LIKES_COUNT': 2032650, 'FILM_REVIEW_COUNT': 295813, 'FILM_LIST_COUNT': 493539, 'FILM_RATING': 4.57, 'FILM_RATING_COUNT': 2600927, 'CREATED_AT': '2024-02-27 16:54:26.145539'}
#
# Entry for Parasite (f_0hTha) in the FILM_STREAMING_SERVICES table is:
# {'FILM_ID': 'f_0hTha', 'STREAMING_SERVICE_ABBR': 'netflix', 'STREAMING_SERVICE_FULL': 'Netflix', 'CREATED_AT': '2024-02-02 16:48:43.277617', 'PRICE': 0, 'VALID': 1}
#
# Entry for Parasite (f_0hTha) in the FILM_GENRE table is:
# {'FILM_ID': 'f_0hTha', 'FILM_GENRE': 'comedy', 'ALL_FILM_GENRES': 'comedy/drama/thriller', 'CREATED_AT': '2023-05-25 18:41:56.064533'}
#
# Entry for Parasite (f_0hTha) in the INGESTED table is:
# {'FILM_ID': 'f_0hTha', 'INGESTION_DATETIME': '2023-04-12 14:25:19.648367'}
#
# Entry for Parasite (f_0hTha) in the TMDB_ID table is:
# {'FILM_ID': 'f_0hTha', 'TMDB_ID': '496243', 'CREATED_AT': '2023-05-24 13:50:06.851936', 'VALID': 1}
#
# Entry for Parasite (f_0hTha) in the FILM_FINANCIALS table is:
# {'FILM_ID': 'f_0hTha', 'FILM_BUDGET': 11363000, 'FILM_REVENUE': 257591776, 'CREATED_AT': '2023-06-30 15:44:01.688715'}
#
# Entry for Parasite (f_0hTha) in the FILM_TMDB_STATS table is:
# {'FILM_ID': 'f_0hTha', 'FILM_POPULARITY': 66.126, 'FILM_VOTE_COUNT': 15924, 'FILM_VOTE_AVERAGE': 8.516, 'CREATED_AT': '2023-06-30 15:44:01.702272'}
#
# Entry for Parasite (f_0hTha) in the FILM_LANGUAGE table is:
# {'FILM_ID': 'f_0hTha', 'FILM_LANGUAGE': 'ko', 'CREATED_AT': None}
#
# Entry for Parasite (f_0hTha) in the FILM_RELEASE_INFO table is:
# {'FILM_ID': 'f_0hTha', 'FILM_RELEASE_DATE': '2019-05-30', 'FILM_STATUS': 'Released', 'CREATED_AT': '2023-06-30 15:44:01.715534'}
#
# Entry for Parasite (f_0hTha) in the FILM_RUNTIME table is:
# {'FILM_ID': 'f_0hTha', 'FILM_RUNTIME': 133, 'CREATED_AT': None}
#
# Entry for Parasite (f_0hTha) in the FILM_KEYWORDS table is:
# [{'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 5732, 'KEYWORD': 'birthday party', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 5752, 'KEYWORD': 'private lessons', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 9866, 'KEYWORD': 'basement', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 10123, 'KEYWORD': 'dark comedy', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 10453, 'KEYWORD': 'con artist', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 11935, 'KEYWORD': 'working class', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 12565, 'KEYWORD': 'psychological thriller', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 14514, 'KEYWORD': 'class differences', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 17997, 'KEYWORD': 'housekeeper', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 18015, 'KEYWORD': 'tutor', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 18035, 'KEYWORD': 'family', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 33421, 'KEYWORD': 'crime family', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 198673, 'KEYWORD': 'unemployed', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 237462, 'KEYWORD': 'wealthy family', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 261681, 'KEYWORD': 'south korea', 'CREATED_AT': '2023-06-30 15:44:01.727244'}, {'FILM_ID': 'f_0hTha', 'KEYWORD_ID': 290327, 'KEYWORD': 'seoul, south korea', 'CREATED_AT': '2023-06-30 15:44:01.727244'}]
#
# Entry for Parasite (f_0hTha) in the FILM_CAST table is:
# [{'FILM_ID': 'f_0hTha', 'PERSON_ID': 20738, 'CHARACTER': 'Kim Ki-taek', 'CAST_ORDER': 0, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 115290, 'CHARACTER': 'Park Dong-ik', 'CAST_ORDER': 1, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 556435, 'CHARACTER': 'Yeon-kyo', 'CAST_ORDER': 2, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1255881, 'CHARACTER': 'Ki-woo', 'CAST_ORDER': 3, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1442583, 'CHARACTER': 'Ki-jung', 'CAST_ORDER': 4, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1572354, 'CHARACTER': 'Moon-gwang', 'CAST_ORDER': 5, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2158882, 'CHARACTER': 'Chung-sook', 'CAST_ORDER': 6, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1694435, 'CHARACTER': 'Geun-se', 'CAST_ORDER': 7, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1418762, 'CHARACTER': 'Da-hye', 'CAST_ORDER': 8, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2306987, 'CHARACTER': 'Da-song', 'CAST_ORDER': 9, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1709230, 'CHARACTER': 'Driver Yoon', 'CAST_ORDER': 10, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2326809, 'CHARACTER': 'Pizza manager', 'CAST_ORDER': 11, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2478772, 'CHARACTER': 'Pizza man', 'CAST_ORDER': 12, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2326615, 'CHARACTER': 'Neighbor', 'CAST_ORDER': 13, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2478781, 'CHARACTER': 'Drunk 1', 'CAST_ORDER': 14, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2379047, 'CHARACTER': 'Street man', 'CAST_ORDER': 15, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2499966, 'CHARACTER': 'Benz Dealer', 'CAST_ORDER': 16, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1419705, 'CHARACTER': 'VR Specialist', 'CAST_ORDER': 17, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2159392, 'CHARACTER': 'Drunk 2', 'CAST_ORDER': 18, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2538209, 'CHARACTER': 'Mart cashier', 'CAST_ORDER': 19, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2114604, 'CHARACTER': 'Party man', 'CAST_ORDER': 20, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1537955, 'CHARACTER': 'Party man', 'CAST_ORDER': 21, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2320125, 'CHARACTER': 'A Singer', 'CAST_ORDER': 22, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1895563, 'CHARACTER': 'Cellist', 'CAST_ORDER': 23, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2479225, 'CHARACTER': 'Party woman', 'CAST_ORDER': 24, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2479219, 'CHARACTER': 'Party man', 'CAST_ORDER': 25, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2478778, 'CHARACTER': 'Italy Chef', 'CAST_ORDER': 26, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2478782, 'CHARACTER': 'Doctor', 'CAST_ORDER': 27, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2478780, 'CHARACTER': 'Detective', 'CAST_ORDER': 28, 'CREATED_AT': '2023-06-30 15:44:01.749798'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2478774, 'CHARACTER': 'JTBC Reporter', 'CAST_ORDER': 29, 'CREATED_AT': '2023-06-30 15:44: ...
#
# Entry for Parasite (f_0hTha) in the FILM_COLLECTIONS table is:
# {'FILM_ID': 'f_0hTha', 'COLLECTION_ID': -1, 'COLLECTION_NAME': '', 'CREATED_AT': '2023-06-30 15:44:01.812224'}
#
# Entry for Parasite (f_0hTha) in the IMDB_ID table is:
# {'FILM_ID': 'f_0hTha', 'IMDB_ID': 'tt6751668', 'CREATED_AT': '2023-05-24 13:50:06.836277'}
#
# Entry for Parasite (f_0hTha) in the CONTENT_TYPE table is:
# {'FILM_ID': 'f_0hTha', 'CONTENT_TYPE': 'movie', 'CREATED_AT': '2023-05-24 13:50:06.851936'}
#
# Entry for Parasite (f_0hTha) in the FILM_CREW table is:
# [{'FILM_ID': 'f_0hTha', 'PERSON_ID': 21684, 'JOB': 'Screenplay', 'CREATED_AT': '2023-06-30 15:44:01.795901'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 21684, 'JOB': 'Director', 'CREATED_AT': '2023-06-30 15:44:01.795901'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 68909, 'JOB': 'Director of Photography', 'CREATED_AT': '2023-06-30 15:44:01.795901'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 1674268, 'JOB': 'Editor', 'CREATED_AT': '2023-06-30 15:44:01.795901'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2127965, 'JOB': 'Original Music Composer', 'CREATED_AT': '2023-06-30 15:44:01.795901'}, {'FILM_ID': 'f_0hTha', 'PERSON_ID': 2320121, 'JOB': 'Screenplay', 'CREATED_AT': '2023-06-30 15:44:01.795901'}]
#
# No Entry for Parasite (f_0hTha) in the PERSON_INFO table.
#
# Entry for Parasite (f_0hTha) in the FILM_URL_TITLE table is:
# {'FILM_ID': 'f_0hTha', 'FILM_URL_TITLE': 'parasite-2019', 'CREATED_AT': '2023-05-25 18:41:56.032467'}
#
# Entry for Parasite (f_0hTha) in the WATCHED table is:
# {'FILM_ID': 'f_0hTha'}
#
# Entry for Parasite (f_0hTha) in the WATCHLIST table is:
# {}
#
# Entry for Parasite (f_0hTha) in the FILM_TITLE table is:
# {'FILM_ID': 'f_0hTha', 'FILM_TITLE': 'Parasite', 'LETTERBOXD_URL': 'https://boxd.it/hTha'}
#
# Entry for Parasite (f_0hTha) in the PERSONAL_RANKING table is:
# {'FILM_ID': 'f_0hTha', 'FILM_POSITION': 25}
#
VING THE WORLD': 0.0, 'SERIES OF MURDERS': 0.0, 'SPACE MARINE': 0.0, 'SPACE OPERA': 0.0, 'SPACE TRAVEL': 0.0, 'SUMMER CAMP': 0.0, 'SUPERNATURAL HORROR': 0.0, 'SUPERNATURAL POWER': 0.0, 'SURVIVAL HORROR': 0.0, 'TIME LOOP': 0.0, 'UNDEAD': 0.0, 'VIDEO NASTY': 0.0, 'VIRTUAL REALITY': 0.0, 'WHODUNIT': 0.0, 'WITCHCRAFT': 0.0, 'WOODS': 0.0, 'FILM_RATING_SCALED': 4.875, 'ALGO_SCORE': None}
#
# Entry for Parasite (f_0hTha) in the FILM_SHAP_VALUES table is:
# {}
#
# Entry for Parasite (f_0hTha) in the FILM_LETTERBOXD_TOP_250 table is:
# {'FILM_ID': 'f_0hTha', 'TOP_250_POSITION': 7}

# %%
import requests
from bs4 import BeautifulSoup
film_id = 'f_012Ci'
film_url_title = get_from_table('FILM_URL_TITLE', film_id, 'FILM_URL_TITLE')
initial_url = 'https://letterboxd.com/film/{}/members/rated/.5-5/'.format(film_url_title)
r = requests.get(initial_url)

soup = BeautifulSoup(r.content, 'lxml')

# %%
# Out:
# 'dead-kids-1981'

# %%
soup.find_all('a', {'class': 'tooltip'})
# Out:
# [<a class="tooltip" href="/film/dead-kids-1981/members/" title="6,439 people">
#  				Members
#  			</a>,
#  <a class="tooltip" href="/film/dead-kids-1981/fans/" title="1 fan">
#  				Fans
#  			</a>,
#  <a class="tooltip" href="/film/dead-kids-1981/likes/" title="1,381 likes">
#  				Likes
#  			</a>,
#  <a class="tooltip" href="/film/dead-kids-1981/reviews/" title="1,394 reviews">
#  				Reviews
#  			</a>,
#  <a class="tooltip" href="/film/dead-kids-1981/lists/" title="4,721 lists">
#  				Lists
#  			</a>,
#  <a class="has-icon icon-16 icon-review tooltip" data-username="rejectedslasher" href="/rejectedslasher/film/dead-kids-1981/" title="Read review">Review</a>,
#  <a class="has-icon icon-16 icon-review tooltip" data-username="ghlewmer" href="/ghlewmer/film/dead-kids-1981/" title="Read review">Review</a>,
#  <a class="has-icon icon-16 icon-review tooltip" data-username="shawnr60" href="/shawnr60/film/dead-kids-1981/" title="Read review">Review</a>,
#  <a class="trigger tooltip" href="https://twitter.com/letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on X">
#  <svg aria-hidden="true" class="glyph" height="17" role="presentation" width="17" xmlns="http://www.w3.org/2000/svg"><path d="m5.4 0 4 6 5-6h2.1l-.3.4-5.9 6.8 6.5 9.5.2.3h-5.3l-4.3-6.3L2 16.9 2 17H0l.3-.4 6.2-7.2L.3.4 0 0h5.3Zm-1 1.5H2.9l4.9 7 .6.9 4.3 6.1h1.6l-5-7.3-.7-.9-4-5.8Z" fill-rule="nonzero"></path></svg>
#  <span class="label">X</span>
#  </a>,
#  <a class="trigger tooltip" href="https://www.threads.net/@letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on Threads">
#  <svg aria-hidden="true" class="glyph" height="18" role="presentation" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M
.39.78.73 1.13.34.34.67.55 1.12.73.35.13.86.29 1.82.33.83.04 1.2.05 2.7.06h2.47c1.51 0 1.87-.02 2.71-.06a5.4 5.4 0 0 0 1.81-.33c.46-.18.78-.4 1.12-.73.35-.35.56-.67.73-1.13.14-.34.3-.86.34-1.8a49 49 0 0 0 .06-2.72V8.77a49 49 0 0 0-.06-2.71 5.4 5.4 0 0 0-.34-1.82 3.02 3.02 0 0 0-.73-1.12 3.02 3.02 0 0 0-1.12-.73 5.4 5.4 0 0 0-1.81-.33c-.88-.04-1.23-.06-2.93-.06ZM10 4.86a5.14 5.14 0 1 1 0 10.28 5.14 5.14 0 0 1 0-10.28ZM10 7a3 3 0 1 0 0 6 3 3 0 0 0 0-6Zm5.25-3.5a1.25 1.25 0 1 1 0 2.5 1.25 1.25 0 0 1 0-2.5Z"></path></svg>
#  <span class="label">Instagram</span>
#  </a>,
#  <a class="trigger tooltip" href="https://www.tiktok.com/@letterboxd" rel="noopener noreferrer" target="_blank" title="Letterboxd on TikTok">
#  <svg aria-hidden="true" class="glyph" height="18" role="presentation" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M16.48 4.32a4.62 4.62 0 0 1-3.92-2.66A4.04 4.04 0 0 1 12.23 0H9.07v11.85c0 1.93-1.19 3.07-2.65 3.07a2.71 2.71 0 0 1-2.04-.9 2.57 2.57 0 0 1-.6-2.1 2.55 2.55 0 0 1 1.26-1.81 2.7 2.7 0 0 1 2.24-.21V6.77a5.92 5.92 0 0 0-4.08.86 5.7 5.7 0 0 0-2.15 2.55 5.53 5.53 0 0 0 1.26 6.16 5.86 5.86 0 0 0 6.33 1.23 5.78 5.78 0 0 0 2.6-2.08c.64-.94.98-2.03.98-3.15V5.96a7.74 7.74 0 0 0 4.25 1.25V4.32Z"></path></svg>
#  <span class="label">TikTok</span>
#  </a>,
#  <a class="trigger tooltip" href="https://www.youtube.com/letterboxdhq" rel="noopener noreferrer" target="_blank" title="Letterboxd on YouTube">
#  <svg aria-hidden="true" class="glyph" height="16" role="presentation" width="23" xmlns="http://www.w3.org/2000/svg"><path d="M11.74 0c.61 0 2.33.02 4.11.08l.54.02c1.7.06 3.35.18 4.1.38a2.87 2.87 0 0 1 2.03 2.02c.45 1.67.48 5.04.48 5.46v.08c0 .42-.03 3.8-.48 5.46a2.87 2.87 0 0 1-2.03 2.02c-.75.2-2.4.32-4.1.38l-.54.02c-1.78.07-3.5.08-4.11.08H11.26c-.62 0-2.33-.01-4.11-.08l-.54-.02c-1.7-.06-3.36-.18-4.1-.38A2.87 2.87 0 0 1 .48 13.5C.04 11.9 0 8.68 0 8.1v-.2c0-.58.04-3.79.48-5.4A2.87 2.87 0 0 1 2.5.48c.74-.2 2.4-.32 4.1-.38l.54-.02C8.93.02 10.65 0 11.26 0ZM9 4.57v6.86L15 8 9 4.57Z"></path></svg>
#  <span class="label">YouTube</span>
#  </a>]

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-mobile no-js" id="html" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=1024" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="Everyone who has watched Dead Kids" name="description"/>
# <meta content="https://letterboxd.com/film/dead-kids-1981/members/rated/.5-5/" property="og:url"/>
# <meta content="Everyone who has watched Dead Kids" property="og:title"/>
# <meta content="Everyone who has watched Dead Kids" property="og:description"/>
# <meta content="https://s.ltrbxd.com/static/img/default-share.e38c5d62.png" property="og:image"/>
# <meta content="Letterboxd" name="application-name"/>
# <meta content="#14181C" name="theme-color"/>
# <meta content="#445566" name="msapplication-TileColor"/>
# <meta content="app-id=1054271011, affiliate-data=11l5KW, app-argument=https://letterboxd.com/film/dead-kids-1981/members/rated/.5-5/" name="apple-itunes-app"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <title>‎Everyone who has watched Dead Kids • Letterboxd</title>
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		function ga() {}
# 	</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-D3ECBB4D7L"></script>
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		gtag('js', new Date());
#
# 		var analytic_params = {};
#
#
# 		analytic_params['user_type'] = 'Visitor';
# 		analytic_params['template'] = '/object/film/watches';
#
#
#
# 		if (analytic_params.member_type) {
# 			gtag('set', 'user_properties', {
# 				member_type: analytic_params.member_type,
# 			});
# 			delete analytic_params.member_type;
# 		}
# 		var config = {
# 			...analytic_params,
# 			'cookie_domain': 'letterboxd.com',
# 			'optimize_id': 'GTM-TB8HSDN',
# 		};
# 		gtag('config', 'G-D3ECBB4D7L', config);
# 	</script>
# <script>
#
# 		((r, n) => {
# 			r.dataset.useragent = n.userAgent
# 			r.dataset.platform = n.platform
# 		})(document.documentElement, navigator)
#
# 		var isMobile = false,
# 			isMobileOptimised = true,
# 			renderMobile = false,
# 			useStaticFonts = false,
# 			disableFrameProtection = false,
# 			baseURL = "",
# 			successMessages = [],
# 			errorMessages = [],
# 			stickyMessages = [],
# 			globals = {
# 			autoAddFilm: false
# 				, spinners: {
# 					ajax_242d35: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_12_2C3641: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_14_20272f: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif',
# 					spinner_16_161B21: 'https://s.ltrbxd.com/static/img/spinner-dark-2x.fda24f88.gif'
# 				}
# 			},
# 			supermodelCSRF = "",
# 			gRecaptchaKey = '6Le3mMIUAAAAAEXbwZ7M1R5jEv0V5xbvj7bgXq2g',
# 			geolocation = {
# 				country: ""
# 			},
# 			person = {
# 				username: ""
# 				, loggedIn: false
#
# 				, showAds: true
# 				, role: "guest"
# 				, hasExtendedServiceFilters: false
# 				, canBulkAddToLists: false
# 				, canFilterOwned: false
# 				, hasHqRole: false
# 				, canHaveHqDashboard: false
# 				, hasMemberStatistics: false
# 				, blockedMembers: []
# 				, showAdultContent: false
# 				, validated: null
# 				, trusted: false
# 				, hasBlocked : function(member) { for (var i = 0; i !== person.blockedMembers.length; i++) {if (person.blockedMembers[i] === member) return true;} return false; }
# 				, viewingTags: []
# 				, hasMoreTags: true
# 				, getCustomPoster : function(filmId) { return null; }
# 			},
# 			disableAds = false;
#
#
#
# supermodelCSRF = '451dd6d57aa3e97fb7be'; geolocation.country = 'GB';
#
#
#
#
#
#
#
#
#
#
# 				if ( screen.width < 768 ) {
# 					var date = new Date();
# 					var maxAge = 365 * 24 * 60 * 60;
# 					date.setTime(date.getTime() + maxAge * 1000);
# 					var expires = '; expires=' + date.toUTCString();
# 					document.cookie = "useMobileSite=yes" + expires + "; path=/; maxAge=" + maxAge;
# 					if ( document.cookie && document.cookie.indexOf("useMobileSite=yes") >= 0 ) {
# 						window.location.reload(true);
# 					} else {
# 						// No cookies.  No Mobile version.
# 					}
# 				}
#
#
#
#
# 			var filmData = { id: 24839, name: "Dead Kids", releaseYear: "1981", posterURL: "/film/dead-kids-1981/image-150/", path: "/film/dead-kids-1981/", runTime: 99 };
#
#
# 		;((data) => {
# 			// data.assetPaths = data.assetPaths || {}
# 			data.assetPaths = {
# 				'egg-mi': ['https://s.ltrbxd.com/static/js/egg-mi.min.dd88c5f3.js', 'https://s.ltrbxd.com/static/css/egg-mi.min.310c513c.css']
# 			}
# 		})(window.__BXD_DATA = window.__BXD_DATA || {})
# 	</script>
# <script>
# 		window.ramp = window.ramp || {};
# 		window.ramp.que = window.ramp.que || [];
# 		window.ramp.passiveMode = false;
# 		window.ramp.forcePath = '';
# 		window.ramp.custom_tags = [
# 			'',
# 			'',
# 			'',
# 			'',
# 			'',
# 			''
# 		];
# 	</script>
# <script src="//cdn.intergient.com/1024338/72804/ramp_config.js"></script>
# <script>
# 		window._pwGA4PageviewId = ''.concat(Date.now());
# 		window.dataLayer = window.dataLayer || [];
# 		window.gtag = window.gtag || function () {
# 			dataLayer.push(arguments);
# 		};
# 		gtag('js', new Date());
# 		gtag('config', 'G-L0W7RDZXX3', { 'send_page_view': false });
# 		gtag(
# 			'event',
# 			'ramp_js',
# 			{
# 				'send_to': 'G-L0W7RDZXX3',
# 				'pageview_id': window._pwGA4PageviewId
# 			}
# 		);
#
# 		(function() {
# 			const userAgent = navigator.userAgent || navigator.vendor || window.opera;
# 			window.isAndroid = new RegExp("android", "i").test(userAgent);
# 			window.isIOS = new RegExp("iPad|iPhone|iPod", "i").test(userAgent) && !window.MSStream;
# 			window.adsLocation = 'GB';
# 		})();
# 	</script>
# <link href="/manifest.json" rel="manifest"/>
# <link href="/humans.txt" rel="author" type="text/plain"/>
# <link color="#445566" href="https://s.ltrbxd.com/static/img/icons/letterboxd-decal-l-16px.5fe24c7d.svg" rel="mask-icon"/>
# <link href="https://s.ltrbxd.com/static/img/icons/touch-icon-192x192.257b84e7.png" rel="shortcut icon" sizes="196x196"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/static/opensearch.xml" rel="search" title="Letterboxd" type="application/opensearchdescription+xml"/>
# <link href="https://s.ltrbxd.com/static/css/main.min.64208282.css" media="screen, projection" rel="stylesheet"/>
# <link href="https://s.ltrbxd.com/static/css/desktop.min.86f859c3.css" media="screen, projection" rel="stylesheet"/>
# <script src="https://s.ltrbxd.com/static/js/main.min.c8f252bd.js"></script>
# <script>
# 		if ( $.cookie("letterboxd.admin.signed.in") === person.username ) {
# 			successMessages.push("You are signed in as " + person.username);
# 			$(function(){$("#header, #content, body").css("background","#543");});
# 		}
# 	</script>
# </head>
# <body class="views">
# <script>
# var mainMenu = [];
#
#
# 	mainMenu.push({
# 		"id": 1,
# 		"url": "/sign-in/",
# 		"name": "Sign in",
# 		"cssClassCode": "sign-in-menu",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": true,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 2,
# 		"url": "/create-account/",
# 		"name": "Create account",
# 		"cssClassCode": "create-account-menu",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 3,
# 		"url": "/",
# 		"name": "Home",
# 		"cssClassCode": "person-home",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 4,
# 		"url": "/activity/",
# 		"name": "Activity",
# 		"cssClassCode": "main-nav-activity",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "Activity",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 5,
# 		"url": "/films/",
# 		"name": "Films",
# 		"cssClassCode": "films-page main-nav-films",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 6,
# 		"url": "/lists/",
# 		"name": "Lists",
# 		"cssClassCode": "lists-page main-nav-lists",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 7,
# 		"url": "/members/",
# 		"name": "Members",
# 		"cssClassCode": "main-nav-people",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 8,
# 		"url": "/journal/",
# 		"name": "Journal",
# 		"cssClassCode": "main-nav-journal",
# 		"hideWhenSignedIn": false,
# 		"hideWhenNotSignedIn": false,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
#
# 	mainMenu.push({
# 		"id": 9,
# 		"url": "/search/",
# 		"name": "Search results",
# 		"cssClassCode": "",
# 		"hideWhenSignedIn": true,
# 		"hideWhenNotSignedIn": true,
# 		"showInMainNavForMobile": false,
# 		"tooltip": "",
# 		"selected": false
# 	});
#
# </script>
# <header class="site-header js-hide-in-app" id="header">
# <div class="site-header-bg"></div>
# <section>
# <h1 class="site-logo"><a class="logo replace" href="/">Letterboxd — Your life in film</a></h1>
# <div class="react-component" data-component-class="globals.comps.NavComponent"></div>
# <form action="#" autocapitalize="off" autocorrect="off" class="signin signin-form js-header-signin-form js-signin" data-recaptcha-action="signin" data-url="/user/login.do" id="signin" method="post" novalidate="novalidate">
# <input name="__csrf" type="hidden" value="placeholder"/>
# <input name="authenticationCode" type="hidden" value=""/>
# <fieldset class="fieldset">
# <div class="fields">
# <div class="col">
# <label for="username">Username</label>
# <input autocomplete="email" class="field signin-field" data-focus-control="signingIn" id="username" inputmode="email" name="username" tabindex="1" type="email" value=""/>
# </div>
# <div class="col">
# <label for="password">Password</label>
# <input autocomplete="current-password" class="field signin-field" id="password" name="password" tabindex="2" type="password" value=""/>
# </div>
# <div class="signin-actions">
# <label class="option-label -checkbox -small" for="remember">
# <input class="checkbox" id="remember" name="remember" tabindex="3" type="checkbox" value="true"/><i class="substitute"></i>
# <span class="focus">Remember<span class="mob-hide"> me</span></span>
# </label>
# <p class="reset" tabindex="5"><a class="reset-password-link" href="/user/request-password-reset" target="_top">Forgotten<span class="elongated"> username or password</span>?</a></p>
# </div>
# <div class="col buttons">
# <div class="button-container"><input class="button -action button-green" tabindex="4" type="submit" value="Sign in"/><i></i></div>
# <div class="close js-close-signin">×</div>
# </div>
# </div>
# </fieldset>
# <div class="errormessage" id="signin-message"></div>
# </form>
# <form action="/search/" autocorrect="off" class="js-search-form search-form" id="search" method="get">
# <input autocomplete="false" name="hidden" style="display:none;" type="text"/>
# <fieldset>
# <label class="hidden" for="search-q">Search:</label>
# <input class="field -borderless" data-lpignore="true" id="search-q" inputmode="search" name="q" type="text" value=""/>
# <input class="action" type="submit" value="Search"/>
# </fieldset>
# </form>
# </section>
# </header>
# <div class="site-body" id="content">
# <div class="content-wrap">
# <div class="cols-2">
# <section class="section col-17 col-main">
# <header class="page-header overflow person-header film-header">
# <div class="contextual-title">
# <h1 class="headline-2 prettify">
# <span class="context">Everyone who has watched</span>
# <a href="/film/dead-kids-1981/">Dead Kids</a> <small class="metadata"><a href="/films/year/1981/">1981</a></small>
# </h1>
# </div>
# </header>
# <div id="content-nav"> <section class="sub-nav-wrapper">
# <ul class="sub-nav">
# <li class="js-route-watches">
# <a class="tooltip" href="/film/dead-kids-1981/members/" title="6,439 people">
# 				Members
# 			</a>
# </li>
# <li class="js-route-fans">
# <a class="tooltip" href="/film/dead-kids-1981/fans/" title="1 fan">
# 				Fans
# 			</a>
# </li>
# <li class="js-route-likes">
# <a class="tooltip" href="/film/dead-kids-1981/likes/" title="1,381 likes">
# 				Likes
# 			</a>
# </li>
# <li class="js-route-reviews">
# <a class="tooltip" href="/film/dead-kids-1981/reviews/" title="1,394 reviews">
# 				Reviews
# 			</a>
# </li>
# <li class="js-route-lists">
# <a class="tooltip" href="/film/dead-kids-1981/lists/" title="4,721 lists">
# 				Lists
# 			</a>
# </li>
# </ul>
# <script id="script-e0314597-d277-4fee-807e-fb0e55d8363a"> ((tag, target) => { let adsScript = null; let adsPlatforms = null; let adsLocations = null; if (!disableAds && person.showAds) { let adUnit = document.createElement('div'); let kicker = [ '<div class="upgrade-kicker -skyscraper js-hide-in-app">', '<button type="button" class="modaltrigger" data-bs-toggle="modal" data-bs-target="#remove-ads-modal">', 'Remove Ads', '<svg aria-hidden="true" width="7" height="7" xmlns="http://www.w3.org/2000/svg"><path d="m.5.5 6 6M6.5.5l-6 6" fill-rule="evenodd" stroke="#000"/></svg>', '</button>', '</div>' ].join(''); if ( adsScript && adsScript === 'bandsintown' && adsPlatforms && ((window.isIOS && adsPlatforms.indexOf("iOS") >= 0) || (window.isAndroid && adsPlatforms.indexOf("Android") >= 0)) && adsLocations && adsLocations.indexOf(window.adsLocation) >= 0 ) { var opts = { artist: "", song: "", adunit_id: 100005950, div_id: "cf_async_e0314597-d277-4fee-807e-fb0e55d8363a" }; adUnit.id = opts.div_id; if (target) { target.insertAdjacentElement('beforeend', adUnit); } else { tag.insertAdjacentElement('afterend', adUnit); } window.addEventListener('DOMContentLoaded', (event) => { adUnit.insertAdjacentHTML('afterend', kicker); }, { once: true }); var c=function(){cf.showAsyncAd(opts)};if(typeof window.cf !== 'undefined')c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="//srv.tunefindforfans.com/fruits/apricots.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)}; } else { adUnit.id = 'pw-e0314597-d277-4fee-807e-fb0e55d8363a'; adUnit.className = 'pw-div'; adUnit.setAttribute('data-pw-' + (renderMobile ? 'mobi' : 'desk'), 'sky_atf'); if (target) { target.insertAdjacentElement('beforeend', adUnit); } else { tag.insertAdjacentElement('afterend', adUnit); } window.addEventListener('DOMContentLoaded', (event) => { adUnit.insertAdjacentHTML('afterend', kicker); window.ramp.que.push(function () { window.ramp.addTag('pw-e0314597-d277-4fee-807e-fb0e55d8363a'); }); }, { once: true }); } } tag.remove(); })(document.getElementById('script-e0314597-d277-4fee-807e-fb0e55d8363a')); </script>
# </aside>
# </div>
# </div>
# </div>
# <footer class="page-footer js-page-footer js-hide-in-app" id="page-footer">
# <div class="content-wrap">
# <nav class="footer-nav js-footer-nav">
# <ul>
# <li><a href="/about/">About</a></li>
# <li><a href="/journal/">News</a></li>
# <li class="js-hide-in-app"><a href="/pro/">Pro</a></li>
# <li><a href="/apps/">Apps</a></li>
# <li><a href="https://apple.co/3TfzHVG" rel="noopener noreferrer" target="_blank">Podcast</a></li>
# <li><a href="/year-in-review/">Year in Review</a></li>
# <li><a href="/gift-guide/">Gift Guide</a></li>
# <li><a href="/welcome/">Help</a></li>
# <li><a href="/legal/terms-of-use/">Terms</a></li>
# <li><a href="/api-beta/">API</a></li>
# <li><a href="/contact/">Contact</a></li>
# </ul>
# </nav>
# <div class="socials">
# <nav class="social-service-list -inline">
# <div class="listitem -icononly">
# <a class="trigger tooltip" href="https
# <span class="label">YouTube</span>
# </a>
# </div>
# </nav>
# </div>
# <p class="copyright">
# 				© Letterboxd Limited. Made by <a class="mute" href="/crew/">fans</a> in Aotearoa New Zealand.
# 				<span class="nobr"><a class="mute" href="https://letterboxd.com/about/film-data/">Film data</a> from <a class="mute" href="https://www.themoviedb.org">TMDb</a>.
#
# 						<a class="mute mobile-site-switch" data-use-mobile-site="yes" href="#">Mobile site</a>.
#
# 	</span>
# <span class="recap" style="display:none"><br/>This site is protected by reCAPTCHA and the Google <a class="mute" href="https://policies.google.com/privacy" rel="noopener noreferrer" target="_blank">privacy policy</a> and <a class="mute" href="https://policies.google.com/terms" rel="noopener noreferrer" target="_blank">terms of service</a> apply.</span>
# </p>
# </div>
# </footer>
# <form action="" aria-hidden="true" aria-labelledby="poster-picker-modal-title" class="modal fade poster-picker-modal" data-bs-backdrop="static" id="poster-picker-modal" method="post" novalidate="novalidate" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-lg modal-fullscreen-sm-down modal-dialog-centered modal-dialog-scrollable">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="poster-picker-modal-title">Select your preferred <span class="js-image-type">poster</span></h5>
# <button aria-label="Close" class="modal-close" data-bs-dismiss="modal" type="button"></button>
# </div>
# <div class="modal-body">
# <div data-js-target="poster-picker" data-poster-picker-options='{"id": "00b92bbe-cce1-473c-9f2d-dde4cc5f38d5"}' id="poster-picker-00b92bbe-cce1-473c-9f2d-dde4cc5f38d5"></div>
# </div>
# <div class="modal-footer">
# <div class="poster-picker-note"></div>
# <div class="poster-picker-controls" data-poster-picker-controls-for="00b92bbe-cce1-473c-9f2d-dde4cc5f38d5"> <div class="modal-action-group -center"> <button class="button -destructive" data-js-trigger="reset" disabled="" type="button"> <span class="label" data-js-label-for="film">Reset <span class="js-image-type">poster</span></span> <span class="label" data-js-label-for="object" hidden="">Reset for <span class="js-object-name">item</span></span> </button> <button class="button -action" data-js-trigger="submit" disabled="" type="submit"> <span class="label" data-js-label-for="film">Save<span class="mob-hide"> changes</span></span> <span class="label" data-js-label-for="object" hidden="">Save<span class="mob-hide"> for <span class="js-object-name">item</span></span></span> </button> </div> <div aria-hidden="true" class="objectonly js-objectonly" hidden=""> <label class="option-label -checkbox -medium -reversed" for="frm-object-only"> <input class="checkbox" data-js-trigger="object-only" disabled="" id="frm-object-only" type="checkbox" value="true"/><i class="substitute"></i>This <span class="js-object-name">item</span> only </label> </div> </div>
# </div>
# </div>
# </div>
# </form>
# <div aria-hidden="true" aria-labelledby="remove-ads-modal-title" class="modal fade modal-upgrade-message" id="remove-ads-modal" tabindex="-1">
# <div class="modal-dialog modal-dialog-centered">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="remove-ads-modal-title">Upgrade to remove ads</h5>
# <button aria-label="Close" class="modal-close modal-close-white" data-bs-dismiss="modal" type="button"></button>
# </div>
# <div class="modal-body">
# <div class="body-text -hero">
# <p>Letterboxd is an independent service created by a small team, and we rely mostly on the support of our members to maintain our site and apps. Please consider upgrading to a <a href="/pro/">Pro account</a>—for less than a couple bucks a month, you’ll get cool additional features like all-time and annual stats pages (<a href="https://letterboxd.com/jack/stats/">example</a>), the ability to select (and filter by) your favorite streaming services, and no ads!</p>
# </div>
# </div>
# <div class="modal-footer">
# <a class="button -action button-action" href="/pro/">Learn more about Pro</a>
# </div>
# </div>
# </div>
# </div>
# <script defer="" src="https://s.ltrbxd.com/static/js/partner-publishers.min.4e9bca73.js"></script>
# </body>
# </html>

# %%
metrics_dict = {}
for i in ['members', 'fans', 'likes', 'reviews', 'lists']:
    href_str = '/film/{}/{}/'.format(film_url_title, i)
    try:
        metric_string = soup.find('a', {'class': 'tooltip', 'href':href_str}).get('title')
        metric = int(metric_string[:metric_string.find('\xa0')].replace(',', ''))
    except:
        metric = 0
    metrics_dict[i] = metric

# %%
letterboxd_exports_folder_dir = os.path.join(os.getenv('PROJECT_PATH'), 'db/raw_exports')
letterboxd_export_folders = os.listdir(letterboxd_exports_folder_dir)
len(letterboxd_export_folders)
# Out:
# 34

# %%
[x/4 for x in range(5)]
# Out:
# [0.0, 0.25, 0.5, 0.75, 1.0]

# %%
ind_to_keep = [int((len(letterboxd_export_folders)-1) * x) for x in  [0, 0.25, 0.5, 0.75, 1]]
ind_to_keep
# Out:
# [0, 8, 16, 24, 33]

# %%
folders_to_keep = 5

raw_ind_to_keep = [x/(folders_to_keep-1) for x in range(folders_to_keep)]
ind_to_keep = [int((len(letterboxd_export_folders)-1) * x) for x in raw_ind_to_keep]
folders_to_keep = [sorted(letterboxd_export_folders)[x] for x in ind_to_keep]
folders_to_delete = [x for x in letterboxd_export_folders if x not in folders_to_keep]
folders_to_keep
# Out:
# ['letterboxd-td1138-2023-04-05-09-18-utc',
#  'letterboxd-td1138-2023-06-13-15-54-utc',
#  'letterboxd-td1138-2023-06-26-10-06-utc',
#  'letterboxd-td1138-2023-07-04-14-41-utc',
#  'letterboxd-td1138-2023-07-31-23-48-utc']

# %%
raw_ind_to_keep
# Out:
# [0.0, 0.25, 0.5, 0.75, 1.0]

# %%
folders_to_delete
# Out:
# ['letterboxd-td1138-2023-06-02-14-42-utc',
#  'letterboxd-td1138-2023-06-05-05-38-utc',
#  'letterboxd-td1138-2023-06-05-07-52-utc',
#  'letterboxd-td1138-2023-06-06-11-18-utc',
#  'letterboxd-td1138-2023-06-07-16-52-utc',
#  'letterboxd-td1138-2023-06-08-11-27-utc',
#  'letterboxd-td1138-2023-06-13-10-08-utc',
#  'letterboxd-td1138-2023-06-13-16-42-utc',
#  'letterboxd-td1138-2023-06-14-10-39-utc',
#  'letterboxd-td1138-2023-06-15-11-49-utc',
#  'letterboxd-td1138-2023-06-19-21-58-utc',
#  'letterboxd-td1138-2023-06-20-16-10-utc',
#  'letterboxd-td1138-2023-06-22-16-15-utc',
#  'letterboxd-td1138-2023-06-23-17-23-utc',
#  'letterboxd-td1138-2023-06-26-23-06-utc',
#  'letterboxd-td1138-2023-06-27-20-21-utc',
#  'letterboxd-td1138-2023-06-27-23-22-utc',
#  'letterboxd-td1138-2023-06-28-00-21-utc',
#  'letterboxd-td1138-2023-06-28-14-23-utc',
#  'letterboxd-td1138-2023-06-30-14-36-utc',
}
#
# Entry for Southland Tales (f_023Uu) in the FILM_LETTERBOXD_STATS table is:
# {'FILM_ID': 'f_023Uu', 'FILM_WATCH_COUNT': 38186, 'FILM_FAN_COUNT': 339, 'FILM_LIKES_COUNT': 7520, 'FILM_REVIEW_COUNT': 8600, 'FILM_LIST_COUNT': 12394, 'FILM_TOP_250': None, 'FILM_RATING': 2.9, 'FILM_RATING_COUNT': 23177, 'CREATED_AT': '2023-05-23 14:47:55.357009'}
#
# Entry for Southland Tales (f_023Uu) in the FILM_STREAMING_SERVICES table is:
# {'FILM_ID': 'f_023Uu', 'STREAMING_SERVICE_ABBR': 'ast', 'STREAMING_SERVICE_FULL': 'Lionsgate+', 'CREATED_AT': '2023-05-30 10:03:21.151106', 'PRICE': 0, 'VALID': 1}
#
# Entry for Southland Tales (f_023Uu) in the FILM_GENRE table is:
# {'FILM_ID': 'f_023Uu', 'FILM_GENRE': 'comedy', 'ALL_FILM_GENRES': 'comedy/science-fiction/thriller', 'CREATED_AT': '2023-05-25 17:16:44.326227'}
#
# Entry for Southland Tales (f_023Uu) in the INGESTED table is:
# {'FILM_ID': 'f_023Uu', 'INGESTION_DATETIME': '2023-05-23 14:47:55.830505'}
#
# Entry for Southland Tales (f_023Uu) in the TMDB_ID table is:
# {'FILM_ID': 'f_023Uu', 'TMDB_ID': '4723', 'CREATED_AT': '2023-05-24 18:39:41.147769', 'VALID': 1}
#
# Entry for Southland Tales (f_023Uu) in the FILM_FINANCIALS table is:
# {'FILM_ID': 'f_023Uu', 'FILM_BUDGET': 17000000, 'FILM_REVENUE': 374743, 'CREATED_AT': '2023-05-31 00:08:10.407336'}
#
# Entry for Southland Tales (f_023Uu) in the FILM_TMDB_STATS table is:
# {'FILM_ID': 'f_023Uu', 'FILM_POPULARITY': 13.029, 'FILM_VOTE_COUNT': 466, 'FILM_VOTE_AVERAGE': 5.1, 'CREATED_AT': '2023-05-31 00:08:10.417334'}
#
# Entry for Southland Tales (f_023Uu) in the FILM_LANGUAGE table is:
# {'FILM_ID': 'f_023Uu', 'FILM_LANGUAGE': 'en', 'CREATED_AT': '2023-05-23 14:47:55.689190'}
#
# Entry for Southland Tales (f_023Uu) in the FILM_RELEASE_INFO table is:
# {'FILM_ID': 'f_023Uu', 'FILM_RELEASE_DATE': '2007-11-14', 'FILM_STATUS': 'Released', 'CREATED_AT': '2023-05-31 00:08:10.425960'}
#
# Entry for Southland Tales (f_023Uu) in the FILM_RUNTIME table is:
# {'FILM_ID': 'f_023Uu', 'FILM_RUNTIME': 145, 'CREATED_AT': '2023-05-23 14:47:55.704805'}
#
# Entry for Southland Tales (f_023Uu) in the FILM_KEYWORDS table is:
# [{'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 236, 'KEYWORD': 'suicide', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 380, 'KEYWORD': 'sibling relationship', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 470, 'KEYWORD': 'spy', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 530, 'KEYWORD': 'prophecy', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 539, 'KEYWORD': 'middle east', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 949, 'KEYWORD': 'terrorist', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 970, 'KEYWORD': 'parent child relationship', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 1157, 'KEYWORD': 'husband wife relationship', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 1197, 'KEYWORD': 'nevada', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 1453, 'KEYWORD': 'amnesia', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 1501, 'KEYWORD': 'allegory', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 1583, 'KEYWORD': 'mass murder', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 1930, 'KEYWORD': 'kidnapping', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 1936, 'KEYWORD': 'blackmail', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 3541, 'KEYWORD': 'afghanistan', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 4379, 'KEYWORD': 'time travel', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 4654, 'KEYWORD': 'undercover agent', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 5965, 'KEYWORD': 'marxism', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 6212, 'KEYWORD': 'smuggling (contraband)', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 7375, 'KEYWORD': 'twin brother', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 9732, 'KEYWORD': 'film in film', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 9887, 'KEYWORD': 'surrealism', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 10131, 'KEYWORD': 'interracial relationship', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 10150, 'KEYWORD': 'end of the world', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 10410, 'KEYWORD': 'conspiracy', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 13015, 'KEYWORD': 'terrorism', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 156761, 'KEYWORD': 'split personality', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 157222, 'KEYWORD': 'big corporation', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 161891, 'KEYWORD': 'doppelgänger', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 182058, 'KEYWORD': 'government corruption', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 186219, 'KEYWORD': 'southern california', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 186760, 'KEYWORD': 'alternate timeline', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 208179, 'KEYWORD': 'environmental issue', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD_ID': 208731, 'KEYWORD': 'world war iii', 'CREATED_AT': '2023-05-31 00:08:10.435965'}, {'FILM_ID': 'f_023Uu', 'KEYWORD ...
#
# Entry for Southland Tales (f_023Uu) in the FILM_CAST table is:
# [{'FILM_ID': 'f_023Uu', 'PERSON_ID': 18918, 'CHARACTER': 'Boxer Santaros / Jericho Cane', 'CAST_ORDER': 0, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 57599, 'CHARACTER': 'Roland Taverner / Ronald Taverner', 'CAST_ORDER': 1, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 11863, 'CHARACTER': 'Krysta Kapowski / Krysta Now', 'CAST_ORDER': 2, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 12111, 'CHARACTER': 'Private Pilot Abilene', 'CAST_ORDER': 3, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 16855, 'CHARACTER': 'Madeline Frost-Santaros', 'CAST_ORDER': 4, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 39125, 'CHARACTER': 'Fortunio Balducci', 'CAST_ORDER': 5, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 16165, 'CHARACTER': 'Bart Bookman', 'CAST_ORDER': 6, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 5151, 'CHARACTER': 'Dr. Inga Von Westphalen', 'CAST_ORDER': 7, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 22124, 'CHARACTER': 'Shoshana Kapowski', 'CAST_ORDER': 8, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 39126, 'CHARACTER': 'Serpentine', 'CAST_ORDER': 9, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 39127, 'CHARACTER': 'Teri Riley', 'CAST_ORDER': 10, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 87003, 'CHARACTER': 'Dr. Soberin Exx', 'CAST_ORDER': 11, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 135795, 'CHARACTER': 'Bing Zinneman', 'CAST_ORDER': 12, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 230725, 'CHARACTER': 'Vanessa Vera Cruz', 'CAST_ORDER': 13, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 4496, 'CHARACTER': 'Cyndi Pinziki', 'CAST_ORDER': 14, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 38559, 'CHARACTER': 'Walter Mung', 'CAST_ORDER': 15, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 14101, 'CHARACTER': 'Vaughn Smallhouse', 'CAST_ORDER': 16, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 21197, 'CHARACTER': 'General Teena MacArthur', 'CAST_ORDER': 17, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 116075, 'CHARACTER': 'Sheena Gee', 'CAST_ORDER': 18, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 60252, 'CHARACTER': 'Zora Charmichaels', 'CAST_ORDER': 19, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 56322, 'CHARACTER': 'Veronica Mung / Dream', 'CAST_ORDER': 20, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 8436, 'CHARACTER': 'Nana Mae Frost', 'CAST_ORDER': 21, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 12900, 'CHARACTER': 'Baron Von Westphalen', 'CAST_ORDER': 22, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 85500, 'CHARACTER': 'Hideo Takehashi', 'CAST_ORDER': 23, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 19303, 'CHARACTER': 'Simon Theory', 'CAST_ORDER': 24, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 1776994, 'CHARACTER': 'Tab Taverner', 'CAST_ORDER': 25, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 1776996, 'CHARACTER': 'Brandt Huntington', 'CAST_ORDER': 26, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 933579, 'CHARACTER': 'UPU 4 Officer 3', 'CAST_ORDER': 27, 'CREATED_AT': '2023-05-31 00:08:10.451630'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 1777003, 'CHARACTER': 'Jimmy Hermosa',  ...
#
# Entry for Southland Tales (f_023Uu) in the FILM_COLLECTIONS table is:
# {'FILM_ID': 'f_023Uu', 'COLLECTION_ID': -1, 'COLLECTION_NAME': '', 'CREATED_AT': '2023-05-31 00:08:10.498613'}
#
# Entry for Southland Tales (f_023Uu) in the IMDB_ID table is:
# {'FILM_ID': 'f_023Uu', 'IMDB_ID': 'tt0405336', 'CREATED_AT': '2023-05-24 18:39:41.130150'}
#
# Entry for Southland Tales (f_023Uu) in the CONTENT_TYPE table is:
# {'FILM_ID': 'f_023Uu', 'CONTENT_TYPE': 'movie', 'CREATED_AT': '2023-05-24 18:39:41.159892'}
#
# Entry for Southland Tales (f_023Uu) in the FILM_CREW table is:
# [{'FILM_ID': 'f_023Uu', 'PERSON_ID': 1577, 'JOB': 'Director', 'CREATED_AT': '2023-05-31 00:08:10.482982'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 1590, 'JOB': 'Director of Photography', 'CREATED_AT': '2023-05-31 00:08:10.482982'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 1591, 'JOB': 'Editor', 'CREATED_AT': '2023-05-31 00:08:10.482982'}, {'FILM_ID': 'f_023Uu', 'PERSON_ID': 39121, 'JOB': 'Original Music Composer', 'CREATED_AT': '2023-05-31 00:08:10.482982'}]
#
# No Entry for Southland Tales (f_023Uu) in the PERSON_INFO table.
#
# Entry for Southland Tales (f_023Uu) in the FILM_URL_TITLE table is:
# {'FILM_ID': 'f_023Uu', 'FILM_URL_TITLE': 'southland-tales', 'CREATED_AT': '2023-05-25 17:16:44.297383'}
#
# Entry for Southland Tales (f_023Uu) in the WATCHED table is:
# {'FILM_ID': 'f_023Uu'}
#
# Entry for Southland Tales (f_023Uu) in the WATCHLIST table is:
# {}
#
# Entry for Southland Tales (f_023Uu) in the FILM_TITLE table is:
# {'FILM_ID': 'f_023Uu', 'FILM_TITLE': 'Southland Tales', 'LETTERBOXD_URL': 'https://boxd.it/23Uu'}
#
# Entry for Southland Tales (f_023Uu) in the PERSONAL_RANKING table is:
# {'FILM_ID': 'f_023Uu', 'FILM_POSITION': 447}
#
# Entry for Southland Tales (f_023Uu) in the DIARY table is:
# {'FILM_ID': 'f_023Uu', 'WATCH_DATE': '2023-06-01', 'FILM_RATING': 3.5, 'TAGS': 'lionsgate+', 'FIRST_TIME_WATCH': 1, 'IS_NARRATIVE_FEATURE': 1}
#
# No Entry for Southland Tales (f_023Uu) in the RATING_SCALING_DETAILS table.
#
# Entry for Southland Tales (f_023Uu) in the PERSONAL_RATING table is:
# {'FILM_ID': 'f_023Uu', 'FILM_RATING_BASIC': 3.5, 'FILM_RATING_SCALED': 3.2898009950248754, 'FILM_RATING_PERCENT': 0.657960199004975}
#
# Entry for Southland Tales (f_023Uu) in the FILM_ALGO_SCORE table is:
# {}
#
# Entry for Southland Tales (f_023Uu) in the FILM_SHAP_VALUES table is:
# {}

# %%
print_film_db_entries('f_01U58')
# Out:
# Entry for Salem's Lot (f_01U58) in the FILM_YEAR table is:
# {'FILM_ID': 'f_01U58', 'FILM_YEAR': 1979, 'FILM_DECADE': '1970s', 'CREATED_AT': '2023-05-25 19:14:32.607036'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_LETTERBOXD_STATS table is:
# {'FILM_ID': 'f_01U58', 'FILM_WATCH_COUNT': 32150, 'FILM_FAN_COUNT': 51, 'FILM_LIKES_COUNT': 6924, 'FILM_REVIEW_COUNT': 3825, 'FILM_LIST_COUNT': 15246, 'FILM_TOP_250': None, 'FILM_RATING': 3.3, 'FILM_RATING_COUNT': 19872, 'CREATED_AT': '2023-05-15 17:27:05.078580'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_STREAMING_SERVICES table is:
# {'FILM_ID': 'f_01U58', 'STREAMING_SERVICE_ABBR': 'rent', 'STREAMING_SERVICE_FULL': 'Rental', 'CREATED_AT': '2023-05-24 12:04:12.084305', 'PRICE': 3.49, 'VALID': 1}
#
# Entry for Salem's Lot (f_01U58) in the FILM_GENRE table is:
# {'FILM_ID': 'f_01U58', 'FILM_GENRE': 'drama', 'ALL_FILM_GENRES': 'drama/mystery', 'CREATED_AT': '2023-05-25 19:14:32.620051'}
#
# Entry for Salem's Lot (f_01U58) in the INGESTED table is:
# {'FILM_ID': 'f_01U58', 'INGESTION_DATETIME': '2023-05-15 17:27:05.398951'}
#
# Entry for Salem's Lot (f_01U58) in the TMDB_ID table is:
# {'FILM_ID': 'f_01U58', 'TMDB_ID': '16118', 'CREATED_AT': '2023-05-24 18:18:27.166897', 'VALID': 0}
#
# Entry for Salem's Lot (f_01U58) in the FILM_FINANCIALS table is:
# {'FILM_ID': 'f_01U58', 'FILM_BUDGET': None, 'FILM_REVENUE': None, 'CREATED_AT': '2023-05-25 23:03:35.222219'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_TMDB_STATS table is:
# {'FILM_ID': 'f_01U58', 'FILM_POPULARITY': 24.893, 'FILM_VOTE_COUNT': 384, 'FILM_VOTE_AVERAGE': 6.891, 'CREATED_AT': '2023-05-25 23:03:35.243784'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_LANGUAGE table is:
# {'FILM_ID': 'f_01U58', 'FILM_LANGUAGE': 'en', 'CREATED_AT': '2023-05-15 17:27:05.230988'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_RELEASE_INFO table is:
# {'FILM_ID': 'f_01U58', 'FILM_RELEASE_DATE': '1979-11-17', 'FILM_STATUS': 'Released', 'CREATED_AT': '2023-05-25 23:03:35.253797'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_RUNTIME table is:
# {'FILM_ID': 'f_01U58', 'FILM_RUNTIME': 184, 'CREATED_AT': '2023-05-15 17:27:05.241052'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_KEYWORDS table is:
# [{'FILM_ID': 'f_01U58', 'KEYWORD_ID': 818, 'KEYWORD': 'based on novel or book', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 3133, 'KEYWORD': 'vampire', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 1526, 'KEYWORD': 'home', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 1571, 'KEYWORD': 'return', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 2250, 'KEYWORD': 'menace', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 3095, 'KEYWORD': 'antiquary', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 6095, 'KEYWORD': 'house', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 11162, 'KEYWORD': 'miniseries', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 13028, 'KEYWORD': 'writer', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 41393, 'KEYWORD': 'new england', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 155808, 'KEYWORD': 'hometown', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 315058, 'KEYWORD': 'horror', 'CREATED_AT': '2023-05-25 23:03:35.269431'}]
#
# Entry for Salem's Lot (f_01U58) in the FILM_CAST table is:
# [{'FILM_ID': 'f_01U58', 'PERSON_ID': 15956, 'CHARACTER': 'Ben Mears', 'CAST_ORDER': 0, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 2091, 'CHARACTER': 'Richard K. Straker', 'CAST_ORDER': 1, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 69070, 'CHARACTER': 'Mark Petrie', 'CAST_ORDER': 2, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 7673, 'CHARACTER': 'Susan Norton', 'CAST_ORDER': 3, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 2007, 'CHARACTER': 'Jason Burke', 'CAST_ORDER': 4, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 121041, 'CHARACTER': 'Bonnie Sawyer', 'CAST_ORDER': 5, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 3339, 'CHARACTER': "Gordon 'Weasel' Phillips", 'CAST_ORDER': 6, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 10477, 'CHARACTER': 'Cully Sawyer', 'CAST_ORDER': 7, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 70746, 'CHARACTER': 'Dr. Bill Norton', 'CAST_ORDER': 8, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 124884, 'CHARACTER': 'Majorie Glick', 'CAST_ORDER': 9, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 18071, 'CHARACTER': 'Mike Ryerson', 'CAST_ORDER': 10, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 124885, 'CHARACTER': 'Ned Tibbets', 'CAST_ORDER': 11, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 12521, 'CHARACTER': 'Constable Parkins Gillespie', 'CAST_ORDER': 12, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 20753, 'CHARACTER': 'Larry Crockett', 'CAST_ORDER': 13, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 3340, 'CHARACTER': 'Eva Miller', 'CAST_ORDER': 14, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 15972, 'CHARACTER': 'Kurt Barlow', 'CAST_ORDER': 15, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 15746, 'CHARACTER': 'June Petrie', 'CAST_ORDER': 16, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 32479, 'CHARACTER': 'Ann Norton', 'CAST_ORDER': 17, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 119854, 'CHARACTER': 'Ted Petrie', 'CAST_ORDER': 18, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 1339111, 'CHARACTER': 'Father Donald Callahan', 'CAST_ORDER': 19, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 1392000, 'CHARACTER': 'Deputy Constable Nolly Gardner', 'CAST_ORDER': 20, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 19737, 'CHARACTER': 'Danny Glick', 'CAST_ORDER': 21, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 1217520, 'CHARACTER': 'Ralphie Glick', 'CAST_ORDER': 22, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 158944, 'CHARACTER': 'Henry Glick', 'CAST_ORDER': 23, 'CREATED_AT': '2023-05-25 23:03:35.285060'}]
#
# Entry for Salem's Lot (f_01U58) in the FILM_COLLECTIONS table is:
# {'FILM_ID': 'f_01U58', 'COLLECTION_ID': -1, 'COLLECTION_NAME': '', 'CREATED_AT': '2023-05-25 23:03:35.331998'}
#
# Entry for Salem's Lot (f_01U58) in the IMDB_ID table is:
# {'FILM_ID': 'f_01U58', 'IMDB_ID': 'tt0079844', 'CREATED_AT': '2023-05-24 18:18:27.156381'}
#
# Entry for Salem's Lot (f_01U58) in the CONTENT_TYPE table is:
# {'FILM_ID': 'f_01U58', 'CONTENT_TYPE': 'tv', 'CREATED_AT': '2023-05-24 18:18:27.177414'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_CREW table is:
# [{'FILM_ID': 'f_01U58', 'PERSON_ID': 67492, 'JOB': 'Director of Photography', 'CREATED_AT': '2023-05-25 23:03:35.316367'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 69071, 'JOB': 'Editor', 'CREATED_AT': '2023-05-25 23:03:35.316367'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 46332, 'JOB': 'Editor', 'CREATED_AT': '2023-05-25 23:03:35.316367'}]
#
# No Entry for Salem's Lot (f_01U58) in the PERSON_INFO table.
#
# Entry for Salem's Lot (f_01U58) in the FILM_URL_TITLE table is:
# {'FILM_ID': 'f_01U58', 'FILM_URL_TITLE': 'salems-lot', 'CREATED_AT': '2023-05-25 19:14:32.589432'}
#
# Entry for Salem's Lot (f_01U58) in the WATCHED table is:
# {'FILM_ID': 'f_01U58'}
#
# Entry for Salem's Lot (f_01U58) in the WATCHLIST table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the FILM_TITLE table is:
# {'FILM_ID': 'f_01U58', 'FILM_TITLE': "Salem's Lot", 'LETTERBOXD_URL': 'https://boxd.it/1U58'}
#
# Entry for Salem's Lot (f_01U58) in the PERSONAL_RANKING table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the DIARY table is:
# {}
#
# No Entry for Salem's Lot (f_01U58) in the RATING_SCALING_DETAILS table.
#
# Entry for Salem's Lot (f_01U58) in the PERSONAL_RATING table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the FILM_ALGO_SCORE table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the FILM_SHAP_VALUES table is:
# {}

# %%
print_film_db_entries('f_06BLY')
# Out:
# Entry for The Last Showing (f_06BLY) in the FILM_YEAR table is:
# {'FILM_ID': 'f_06BLY', 'FILM_YEAR': 2014, 'FILM_DECADE': '2010s', 'CREATED_AT': '2023-05-25 20:08:29.268661'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_LETTERBOXD_STATS table is:
# {'FILM_ID': 'f_06BLY', 'FILM_WATCH_COUNT': 1226, 'FILM_FAN_COUNT': 0, 'FILM_LIKES_COUNT': 137, 'FILM_REVIEW_COUNT': 183, 'FILM_LIST_COUNT': 438, 'FILM_TOP_250': None, 'FILM_RATING': 2.45, 'FILM_RATING_COUNT': 900, 'CREATED_AT': '2023-05-15 23:42:38.363709'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_STREAMING_SERVICES table is:
# {'FILM_ID': 'f_06BLY', 'STREAMING_SERVICE_ABBR': 'rent', 'STREAMING_SERVICE_FULL': 'Rental', 'CREATED_AT': '2023-05-25 21:41:31.421478', 'PRICE': 3.49, 'VALID': 1}
#
# Entry for The Last Showing (f_06BLY) in the FILM_GENRE table is:
# {'FILM_ID': 'f_06BLY', 'FILM_GENRE': 'thriller', 'ALL_FILM_GENRES': 'thriller', 'CREATED_AT': '2023-05-25 20:08:29.280417'}
#
# Entry for The Last Showing (f_06BLY) in the INGESTED table is:
# {'FILM_ID': 'f_06BLY', 'INGESTION_DATETIME': '2023-05-15 23:42:38.955383'}
#
# Entry for The Last Showing (f_06BLY) in the TMDB_ID table is:
# {'FILM_ID': 'f_06BLY', 'TMDB_ID': '222887', 'CREATED_AT': '2023-05-15 23:42:33.995260', 'VALID': 1}
#
# Entry for The Last Showing (f_06BLY) in the FILM_FINANCIALS table is:
# {'FILM_ID': 'f_06BLY', 'FILM_BUDGET': 2000000, 'FILM_REVENUE': 0, 'CREATED_AT': '2023-07-04 15:49:02.219525'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_TMDB_STATS table is:
# {'FILM_ID': 'f_06BLY', 'FILM_POPULARITY': 4.349, 'FILM_VOTE_COUNT': 42, 'FILM_VOTE_AVERAGE': 5.3, 'CREATED_AT': '2023-07-04 15:49:02.234665'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_LANGUAGE table is:
# {'FILM_ID': 'f_06BLY', 'FILM_LANGUAGE': 'en', 'CREATED_AT': '2023-05-15 23:42:38.645758'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_RELEASE_INFO table is:
# {'FILM_ID': 'f_06BLY', 'FILM_RELEASE_DATE': '2014-08-22', 'FILM_STATUS': 'Released', 'CREATED_AT': '2023-07-04 15:49:02.246921'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_RUNTIME table is:
# {'FILM_ID': 'f_06BLY', 'FILM_RUNTIME': 89, 'CREATED_AT': '2023-05-15 23:42:38.654942'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_KEYWORDS table is:
# {'FILM_ID': 'f_06BLY', 'KEYWORD_ID': -1, 'KEYWORD': 'none', 'CREATED_AT': '2023-07-04 15:49:02.257807'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_CAST table is:
# [{'FILM_ID': 'f_06BLY', 'PERSON_ID': 5139, 'CHARACTER': 'Stuart', 'CAST_ORDER': 0, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 1223787, 'CHARACTER': 'Martin', 'CAST_ORDER': 1, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 1208295, 'CHARACTER': 'Allie', 'CAST_ORDER': 2, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 1145665, 'CHARACTER': 'Clive', 'CAST_ORDER': 3, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 20056, 'CHARACTER': 'Collins', 'CAST_ORDER': 4, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 62879, 'CHARACTER': 'Jamie', 'CAST_ORDER': 5, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 2563203, 'CHARACTER': 'Cinema Employee', 'CAST_ORDER': 6, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 1208296, 'CHARACTER': 'Anthony', 'CAST_ORDER': 7, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 1160327, 'CHARACTER': 'Officer #1', 'CAST_ORDER': 8, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 2808714, 'CHARACTER': 'Officer #2', 'CAST_ORDER': 9, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 37293, 'CHARACTER': 'Police Officer', 'CAST_ORDER': 10, 'CREATED_AT': '2023-07-04 15:49:02.279039'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 2069441, 'CHARACTER': 'Police Officer', 'CAST_ORDER': 11, 'CREATED_AT': '2023-07-04 15:49:02.279039'}]
#
# Entry for The Last Showing (f_06BLY) in the FILM_COLLECTIONS table is:
# {'FILM_ID': 'f_06BLY', 'COLLECTION_ID': -1, 'COLLECTION_NAME': '', 'CREATED_AT': '2023-07-04 15:49:02.342010'}
#
# Entry for The Last Showing (f_06BLY) in the IMDB_ID table is:
# {'FILM_ID': 'f_06BLY', 'IMDB_ID': 'tt2179239', 'CREATED_AT': '2023-05-15 23:42:33.985694'}
#
# Entry for The Last Showing (f_06BLY) in the CONTENT_TYPE table is:
# {'FILM_ID': 'f_06BLY', 'CONTENT_TYPE': 'movie', 'CREATED_AT': '2023-05-15 23:42:34.003551'}
#
# Entry for The Last Showing (f_06BLY) in the FILM_CREW table is:
# [{'FILM_ID': 'f_06BLY', 'PERSON_ID': 115666, 'JOB': 'Director', 'CREATED_AT': '2023-07-04 15:49:02.325137'}, {'FILM_ID': 'f_06BLY', 'PERSON_ID': 2964911, 'JOB': 'Editor', 'CREATED_AT': '2023-07-04 15:49:02.325137'}]
#
# No Entry for The Last Showing (f_06BLY) in the PERSON_INFO table.
#
# Entry for The Last Showing (f_06BLY) in the FILM_URL_TITLE table is:
# {'FILM_ID': 'f_06BLY', 'FILM_URL_TITLE': 'the-last-showing', 'CREATED_AT': '2023-05-25 20:08:29.258003'}
#
# Entry for The Last Showing (f_06BLY) in the WATCHED table is:
# {'FILM_ID': 'f_06BLY'}
#
# Entry for The Last Showing (f_06BLY) in the WATCHLIST table is:
# {}
#
# Entry for The Last Showing (f_06BLY) in the FILM_TITLE table is:
# {'FILM_ID': 'f_06BLY', 'FILM_TITLE': 'The Last Showing', 'LETTERBOXD_URL': 'https://boxd.it/6BLY'}
#
# Entry for The Last Showing (f_06BLY) in the PERSONAL_RANKING table is:
# {'FILM_ID': 'f_06BLY', 'FILM_POSITION': 814}
#
# Entry for The Last Showing (f_06BLY) in the DIARY table is:
# {'FILM_ID': 'f_06BLY', 'WATCH_DATE': '2021-02-07', 'FILM_RATING': 1.0, 'TAGS': 'physicalmedia', 'FIRST_TIME_WATCH': 1, 'IS_NARRATIVE_FEATURE': 1}
#
# No Entry for The Last Showing (f_06BLY) in the RATING_SCALING_DETAILS table.
#
# Entry for The Last Showing (f_06BLY) in the PERSONAL_RATING table is:
# {'FILM_ID': 'f_06BLY', 'FILM_RATING_BASIC': 1.0, 'FILM_RATING_SCALED': 1.0, 'FILM_RATING_PERCENT': 0.2}
#
# Entry for The Last Showing (f_06BLY) in the FILM_ALGO_SCORE table is:
# {}
#
# Entry for The Last Showing (f_06BLY) in the FILM_SHAP_VALUES table is:
# {}

# %%
compare_film_db_entries(['f_01U58', 'f_0lJBs'])
# Out:
# Entry for Salem's Lot (f_01U58) in the FILM_YEAR table is:
# {'FILM_ID': 'f_01U58', 'FILM_YEAR': 1979, 'FILM_DECADE': '1970s', 'CREATED_AT': '2023-05-25 19:14:32.607036'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_YEAR table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_YEAR': 1975, 'FILM_DECADE': '1970s', 'CREATED_AT': '2023-05-25 18:38:30.581678'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_LETTERBOXD_STATS table is:
# {'FILM_ID': 'f_01U58', 'FILM_WATCH_COUNT': 32150, 'FILM_FAN_COUNT': 51, 'FILM_LIKES_COUNT': 6924, 'FILM_REVIEW_COUNT': 3825, 'FILM_LIST_COUNT': 15246, 'FILM_TOP_250': None, 'FILM_RATING': 3.3, 'FILM_RATING_COUNT': 19872, 'CREATED_AT': '2023-05-15 17:27:05.078580'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_LETTERBOXD_STATS table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_WATCH_COUNT': 550, 'FILM_FAN_COUNT': 0, 'FILM_LIKES_COUNT': 147, 'FILM_REVIEW_COUNT': 99, 'FILM_LIST_COUNT': 189, 'FILM_TOP_250': None, 'FILM_RATING': 3.34, 'FILM_RATING_COUNT': 271, 'CREATED_AT': '2023-05-16 00:25:33.865053'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_STREAMING_SERVICES table is:
# {'FILM_ID': 'f_01U58', 'STREAMING_SERVICE_ABBR': 'rent', 'STREAMING_SERVICE_FULL': 'Rental', 'CREATED_AT': '2023-05-24 12:04:12.084305', 'PRICE': 3.49, 'VALID': 1}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_STREAMING_SERVICES table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the FILM_GENRE table is:
# {'FILM_ID': 'f_01U58', 'FILM_GENRE': 'drama', 'ALL_FILM_GENRES': 'drama/mystery', 'CREATED_AT': '2023-05-25 19:14:32.620051'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_GENRE table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_GENRE': 'animation', 'ALL_FILM_GENRES': 'animation/comedy', 'CREATED_AT': '2023-05-25 18:38:30.592702'}
#
# Entry for Salem's Lot (f_01U58) in the INGESTED table is:
# {'FILM_ID': 'f_01U58', 'INGESTION_DATETIME': '2023-05-15 17:27:05.398951'}
#
# Entry for Tube Tales (f_0lJBs) in the INGESTED table is:
# {'FILM_ID': 'f_0lJBs', 'INGESTION_DATETIME': '2023-05-16 00:25:34.311473'}
#
# Entry for Salem's Lot (f_01U58) in the TMDB_ID table is:
# {'FILM_ID': 'f_01U58', 'TMDB_ID': '16118', 'CREATED_AT': '2023-05-24 18:18:27.166897', 'VALID': 0}
#
# Entry for Tube Tales (f_0lJBs) in the TMDB_ID table is:
# {'FILM_ID': 'f_0lJBs', 'TMDB_ID': '590453', 'CREATED_AT': '2023-07-10 14:12:41.344204', 'VALID': 1}
#
# Entry for Salem's Lot (f_01U58) in the FILM_FINANCIALS table is:
# {'FILM_ID': 'f_01U58', 'FILM_BUDGET': None, 'FILM_REVENUE': None, 'CREATED_AT': '2023-05-25 23:03:35.222219'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_FINANCIALS table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_BUDGET': 0, 'FILM_REVENUE': 0, 'CREATED_AT': '2023-05-25 22:38:33.107014'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_TMDB_STATS table is:
# {'FILM_ID': 'f_01U58', 'FILM_POPULARITY': 24.893, 'FILM_VOTE_COUNT': 384, 'FILM_VOTE_AVERAGE': 6.891, 'CREATED_AT': '2023-05-25 23:03:35.243784'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_TMDB_STATS table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_POPULARITY': 0.6, 'FILM_VOTE_COUNT': 0, 'FILM_VOTE_AVERAGE': 0.0, 'CREATED_AT': '2023-05-25 22:38:33.131696'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_LANGUAGE table is:
# {'FILM_ID': 'f_01U58', 'FILM_LANGUAGE': 'en', 'CREATED_AT': '2023-05-15 17:27:05.230988'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_LANGUAGE table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_LANGUAGE': 'en', 'CREATED_AT': '2023-05-16 00:25:34.136843'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_RELEASE_INFO table is:
# {'FILM_ID': 'f_01U58', 'FILM_RELEASE_DATE': '1979-11-17', 'FILM_STATUS': 'Released', 'CREATED_AT': '2023-05-25 23:03:35.253797'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_RELEASE_INFO table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_RELEASE_DATE': '1975-01-01', 'FILM_STATUS': 'Released', 'CREATED_AT': '2023-05-25 22:38:33.138387'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_RUNTIME table is:
# {'FILM_ID': 'f_01U58', 'FILM_RUNTIME': 184, 'CREATED_AT': '2023-05-15 17:27:05.241052'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_RUNTIME table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_RUNTIME': 3, 'CREATED_AT': '2023-05-16 00:25:34.145844'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_KEYWORDS table is:
# [{'FILM_ID': 'f_01U58', 'KEYWORD_ID': 818, 'KEYWORD': 'based on novel or book', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 3133, 'KEYWORD': 'vampire', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 1526, 'KEYWORD': 'home', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 1571, 'KEYWORD': 'return', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 2250, 'KEYWORD': 'menace', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 3095, 'KEYWORD': 'antiquary', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 6095, 'KEYWORD': 'house', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 11162, 'KEYWORD': 'miniseries', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 13028, 'KEYWORD': 'writer', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 41393, 'KEYWORD': 'new england', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 155808, 'KEYWORD': 'hometown', 'CREATED_AT': '2023-05-25 23:03:35.269431'}, {'FILM_ID': 'f_01U58', 'KEYWORD_ID': 315058, 'KEYWORD': 'horror', 'CREATED_AT': '2023-05-25 23:03:35.269431'}]
#
# Entry for Tube Tales (f_0lJBs) in the FILM_KEYWORDS table is:
# {'FILM_ID': 'f_0lJBs', 'KEYWORD_ID': -1, 'KEYWORD': 'none', 'CREATED_AT': '2023-05-25 22:38:33.138387'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_CAST table is:
# [{'FILM_ID': 'f_01U58', 'PERSON_ID': 15956, 'CHARACTER': 'Ben Mears', 'CAST_ORDER': 0, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 2091, 'CHARACTER': 'Richard K. Straker', 'CAST_ORDER': 1, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 69070, 'CHARACTER': 'Mark Petrie', 'CAST_ORDER': 2, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 7673, 'CHARACTER': 'Susan Norton', 'CAST_ORDER': 3, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 2007, 'CHARACTER': 'Jason Burke', 'CAST_ORDER': 4, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 121041, 'CHARACTER': 'Bonnie Sawyer', 'CAST_ORDER': 5, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 3339, 'CHARACTER': "Gordon 'Weasel' Phillips", 'CAST_ORDER': 6, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 10477, 'CHARACTER': 'Cully Sawyer', 'CAST_ORDER': 7, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 70746, 'CHARACTER': 'Dr. Bill Norton', 'CAST_ORDER': 8, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 124884, 'CHARACTER': 'Majorie Glick', 'CAST_ORDER': 9, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 18071, 'CHARACTER': 'Mike Ryerson', 'CAST_ORDER': 10, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 124885, 'CHARACTER': 'Ned Tibbets', 'CAST_ORDER': 11, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 12521, 'CHARACTER': 'Constable Parkins Gillespie', 'CAST_ORDER': 12, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 20753, 'CHARACTER': 'Larry Crockett', 'CAST_ORDER': 13, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 3340, 'CHARACTER': 'Eva Miller', 'CAST_ORDER': 14, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 15972, 'CHARACTER': 'Kurt Barlow', 'CAST_ORDER': 15, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 15746, 'CHARACTER': 'June Petrie', 'CAST_ORDER': 16, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 32479, 'CHARACTER': 'Ann Norton', 'CAST_ORDER': 17, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 119854, 'CHARACTER': 'Ted Petrie', 'CAST_ORDER': 18, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 1339111, 'CHARACTER': 'Father Donald Callahan', 'CAST_ORDER': 19, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 1392000, 'CHARACTER': 'Deputy Constable Nolly Gardner', 'CAST_ORDER': 20, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 19737, 'CHARACTER': 'Danny Glick', 'CAST_ORDER': 21, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 1217520, 'CHARACTER': 'Ralphie Glick', 'CAST_ORDER': 22, 'CREATED_AT': '2023-05-25 23:03:35.285060'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 158944, 'CHARACTER': 'Henry Glick', 'CAST_ORDER': 23, 'CREATED_AT': '2023-05-25 23:03:35.285060'}]
#
# Entry for Tube Tales (f_0lJBs) in the FILM_CAST table is:
# {'FILM_ID': 'f_0lJBs', 'PERSON_ID': -1, 'CHARACTER': '', 'CAST_ORDER': -1, 'CREATED_AT': '2023-05-25 22:38:33.154059'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_COLLECTIONS table is:
# {'FILM_ID': 'f_01U58', 'COLLECTION_ID': -1, 'COLLECTION_NAME': '', 'CREATED_AT': '2023-05-25 23:03:35.331998'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_COLLECTIONS table is:
# {'FILM_ID': 'f_0lJBs', 'COLLECTION_ID': -1, 'COLLECTION_NAME': '', 'CREATED_AT': '2023-05-25 22:38:33.201007'}
#
# Entry for Salem's Lot (f_01U58) in the IMDB_ID table is:
# {'FILM_ID': 'f_01U58', 'IMDB_ID': 'tt0079844', 'CREATED_AT': '2023-05-24 18:18:27.156381'}
#
# Entry for Tube Tales (f_0lJBs) in the IMDB_ID table is:
# {'FILM_ID': 'f_0lJBs', 'IMDB_ID': None, 'CREATED_AT': '2023-07-10 14:12:41.324944'}
#
# Entry for Salem's Lot (f_01U58) in the CONTENT_TYPE table is:
# {'FILM_ID': 'f_01U58', 'CONTENT_TYPE': 'tv', 'CREATED_AT': '2023-05-24 18:18:27.177414'}
#
# Entry for Tube Tales (f_0lJBs) in the CONTENT_TYPE table is:
# {'FILM_ID': 'f_0lJBs', 'CONTENT_TYPE': 'movie', 'CREATED_AT': '2023-07-10 14:12:41.353746'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_CREW table is:
# [{'FILM_ID': 'f_01U58', 'PERSON_ID': 67492, 'JOB': 'Director of Photography', 'CREATED_AT': '2023-05-25 23:03:35.316367'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 69071, 'JOB': 'Editor', 'CREATED_AT': '2023-05-25 23:03:35.316367'}, {'FILM_ID': 'f_01U58', 'PERSON_ID': 46332, 'JOB': 'Editor', 'CREATED_AT': '2023-05-25 23:03:35.316367'}]
#
# Entry for Tube Tales (f_0lJBs) in the FILM_CREW table is:
# {'FILM_ID': 'f_0lJBs', 'PERSON_ID': 57646, 'JOB': 'Director', 'CREATED_AT': '2023-05-25 22:38:33.185383'}
#
# No Entry for Salem's Lot (f_01U58) in the PERSON_INFO table.
#
# No Entry for Tube Tales (f_0lJBs) in the PERSON_INFO table.
#
# Entry for Salem's Lot (f_01U58) in the FILM_URL_TITLE table is:
# {'FILM_ID': 'f_01U58', 'FILM_URL_TITLE': 'salems-lot', 'CREATED_AT': '2023-05-25 19:14:32.589432'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_URL_TITLE table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_URL_TITLE': 'tube-tales-1975', 'CREATED_AT': '2023-05-25 18:38:30.552483'}
#
# Entry for Salem's Lot (f_01U58) in the WATCHED table is:
# {'FILM_ID': 'f_01U58'}
#
# Entry for Tube Tales (f_0lJBs) in the WATCHED table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the WATCHLIST table is:
# {}
#
# Entry for Tube Tales (f_0lJBs) in the WATCHLIST table is:
# {'FILM_ID': 'f_0lJBs', 'ADDED_DATE': '2022-12-20'}
#
# Entry for Salem's Lot (f_01U58) in the FILM_TITLE table is:
# {'FILM_ID': 'f_01U58', 'FILM_TITLE': "Salem's Lot", 'LETTERBOXD_URL': 'https://boxd.it/1U58'}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_TITLE table is:
# {'FILM_ID': 'f_0lJBs', 'FILM_TITLE': 'Tube Tales', 'LETTERBOXD_URL': 'https://boxd.it/lJBs'}
#
# Entry for Salem's Lot (f_01U58) in the PERSONAL_RANKING table is:
# {}
#
# Entry for Tube Tales (f_0lJBs) in the PERSONAL_RANKING table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the DIARY table is:
# {}
#
# Entry for Tube Tales (f_0lJBs) in the DIARY table is:
# {}
#
# No Entry for Salem's Lot (f_01U58) in the RATING_SCALING_DETAILS table.
#
# No Entry for Tube Tales (f_0lJBs) in the RATING_SCALING_DETAILS table.
#
# Entry for Salem's Lot (f_01U58) in the PERSONAL_RATING table is:
# {}
#
# Entry for Tube Tales (f_0lJBs) in the PERSONAL_RATING table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the FILM_ALGO_SCORE table is:
# {}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_ALGO_SCORE table is:
# {}
#
# Entry for Salem's Lot (f_01U58) in the FILM_SHAP_VALUES table is:
# {}
#
# Entry for Tube Tales (f_0lJBs) in the FILM_SHAP_VALUES table is:
# {}
